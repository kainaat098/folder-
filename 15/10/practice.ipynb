# %% [markdown]
# ## Question no.6

# %% [markdown]
# # Practice

# %% [markdown]
# ## Question no.7
# #### remove all occurences of a given element from a list

# %%
l=[1,2,3,4,5,2]
x=2
for i in l:
    if x == i :
        l.remove(2)
print(l)
# Out:
# [1, 3, 4, 5]
